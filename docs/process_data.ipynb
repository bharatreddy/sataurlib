# %% [markdown]
# # This notebook demonstrates how to read the netcdf SSUSI and TIMED data files (in netcdf format) for a given date range (there are multiple files per day), convert them into a single (more user friendly) csv file.

# %%
import os
import datetime
from imagers.ssusi import read_ssusi
from imagers.timed import read_timed_guvi

# %%
# We assume you already downloaded the raw files
# Refer the "download_files" notebook in case
# you already haven't!
# NOTE : ONLY FILES in specific format
# can be read. So make sure you download
# using the procedure defined in the 
# "download_files" notebook.
# The directory where files are stored
rawFileDir = "/tmp/ssusi/" # Make sure you have this dir or create it
prcsdFileDir = "/tmp/ssusi/prcsd"
satList = [ "f16", "f17", "f18" ]
currDate = datetime.datetime( 2015, 4, 9 )
endDate = datetime.datetime( 2015, 4, 9 )
tDelta = datetime.timedelta(days=1)
while currDate <= endDate:
    for currSat in satList:
        currDir = rawFileDir + currSat + "/"
        for root, dirs, files in os.walk(currDir):
            for nd, dd in enumerate(dirs):
                print "processing data --> ",\
                         currDate.strftime("%Y-%m-%d"), " sat-->", currSat
                ssRdObj = read_ssusi.ProcessData( [root + dd + "/"],\
                             prcsdFileDir, currDate )
                ssRdObj.processed_data_to_file()
    currDate += tDelta
# Out:
# processing data -->  2015-04-09  sat--> f16
# currently working with file--> /tmp/ssusi/f16/20110409/PS.APL_V0116S024CE0018_SC.U_DI.A_GP.F16-SSUSI_PA.APL-SDR-DISK_DD.20110409_SN.38558-00_DF.NC
# processing---> 1 / 14 files
# currently working with file--> /tmp/ssusi/f16/20110409/PS.APL_V0116S024CE0018_SC.U_DI.A_GP.F16-SSUSI_PA.APL-SDR-DISK_DD.20110409_SN.38563-00_DF.NC
# processing---> 2 / 14 files
# currently working with file--> /tmp/ssusi/f16/20110409/PS.APL_V0116S024CE0018_SC.U_DI.A_GP.F16-SSUSI_PA.APL-SDR-DISK_DD.20110409_SN.38559-01_DF.NC
# processing---> 3 / 14 files
# currently working with file--> /tmp/ssusi/f16/20110409/PS.APL_V0116S024CE0018_SC.U_DI.A_GP.F16-SSUSI_PA.APL-SDR-DISK_DD.20110409_SN.38565-00_DF.NC
# processing---> 4 / 14 files
# currently working with file--> /tmp/ssusi/f16/20110409/PS.APL_V0116S024CE0018_SC.U_DI.A_GP.F16-SSUSI_PA.APL-SDR-DISK_DD.20110409_SN.38562-00_DF.NC
# processing---> 5 / 14 files
# currently working with file--> /tmp/ssusi/f16/20110409/PS.APL_V0116S024CE0018_SC.U_DI.A_GP.F16-SSUSI_PA.APL-SDR-DISK_DD.20110409_SN.38555-00_DF.NC
# processing---> 6 / 14 files
# currently working with file--> /tmp/ssusi/f16/20110409/PS.APL_V0116S024CE0018_SC.U_DI.A_GP.F16-SSUSI_PA.APL-SDR-DISK_DD.20110409_SN.38560-00_DF.NC
# processing---> 7 / 14 files
# currently working with file--> /tmp/ssusi/f16/20110409/PS.APL_V0116S024CE0018_SC.U_DI.A_GP.F16-SSUSI_PA.APL-SDR-DISK_DD.20110409_SN.38561-00_DF.NC
# processing---> 8 / 14 files
# currently working with file--> /tmp/ssusi/f16/20110409/PS.APL_V0116S024CE0018_SC.U_DI.A_GP.F16-SSUSI_PA.APL-SDR-DISK_DD.20110409_SN.38564-00_DF.NC
# processing---> 9 / 14 files
# currently working with file--> /tmp/ssusi/f16/20110409/PS.APL_V0116S024CE0018_SC.U_DI.A_GP.F16-SSUSI_PA.APL-SDR-DISK_DD.20110409_SN.38554-00_DF.NC
# processing---> 10 / 14 files
# currently working with file--> /tmp/ssusi/f16/20110409/PS.APL_V0116S024CE0018_SC.U_DI.A_GP.F16-SSUSI_PA.APL-SDR-DISK_DD.20110409_SN.38556-00_DF.NC
# processing---> 11 / 14 files
# currently working with file--> /tmp/ssusi/f16/20110409/PS.APL_V0116S024CE0018_SC.U_DI.A_GP.F16-SSUSI_PA.APL-SDR-DISK_DD.20110409_SN.38553-00_DF.NC
# processing---> 12 / 14 files
# currently working with file--> /tmp/ssusi/f16/20110409/PS.APL_V0116S024CE0018_SC.U_DI.A_GP.F16-SSUSI_PA.APL-SDR-DISK_DD.20110409_SN.38557-01_DF.NC
# processing---> 13 / 14 files
# currently working with file--> /tmp/ssusi/f16/20110409/PS.APL_V0116S024CE0018_SC.U_DI.A_GP.F16-SSUSI_PA.APL-SDR-DISK_DD.20110409_SN.38566-00_DF.NC
# processing---> 14 / 14 files
# processing data -->  2015-04-09  sat--> f16
# currently working with file--> /tmp/ssusi/f16/20150409/PS.APL_V0116S024CE0018_SC.U_DI.A_GP.F16-SSUSI_PA.APL-SDR-DISK_DD.20150409_SN.59193-00_DF.NC
# processing---> 1 / 14 files
# currently working with file--> /tmp/ssusi/f16/20150409/PS.APL_V0116S024CE0018_SC.U_DI.A_GP.F16-SSUSI_PA.APL-SDR-DISK_DD.20150409_SN.59194-00_DF.NC
# processing---> 2 / 14 files
# currently working with file--> /tmp/ssusi/f16/20150409/PS.APL_V0116S024CE0018_SC.U_DI.A_GP.F16-SSUSI_PA.APL-SDR-DISK_DD.20150409_SN.59197-00_DF.NC
# processing---> 3 / 14 files
# currently working with file--> /tmp/ssusi/f16/20150409/PS.APL_V0116S024CE0018_SC.U_DI.A_GP.F16-SSUSI_PA.APL-SDR-DISK_DD.20150409_SN.59202-00_DF.NC
# processing---> 4 / 14 files
# currently working with file--> /tmp/ssusi/f16/20150409/PS.APL_V0116S024CE0018_SC.U_DI.A_GP.F16-SSUSI_PA.APL-SDR-DISK_DD.20150409_SN.59199-00_DF.NC
# processing---> 5 / 14 files
# currently working with file--> /tmp/ssusi/f16/20150409/PS.APL_V0116S024CE0018_SC.U_DI.A_GP.F16-SSUSI_PA.APL-SDR-DISK_DD.20150409_SN.59198-01_DF.NC
# processing---> 6 / 14 files
# currently working with file--> /tmp/ssusi/f16/20150409/PS.APL_V0116S024CE0018_SC.U_DI.A_GP.F16-SSUSI_PA.APL-SDR-DISK_DD.20150409_SN.59201-00_DF.NC
# processing---> 7 / 14 files
# currently working with file--> /tmp/ssusi/f16/20150409/PS.APL_V0116S024CE0018_SC.U_DI.A_GP.F16-SSUSI_PA.APL-SDR-DISK_DD.20150409_SN.59206-00_DF.NC
# processing---> 8 / 14 files
# currently working with file--> /tmp/ssusi/f16/20150409/PS.APL_V0116S024CE0018_SC.U_DI.A_GP.F16-SSUSI_PA.APL-SDR-DISK_DD.20150409_SN.59195-00_DF.NC
# processing---> 9 / 14 files
# currently working with file--> /tmp/ssusi/f16/20150409/PS.APL_V0116S024CE0018_SC.U_DI.A_GP.F16-SSUSI_PA.APL-SDR-DISK_DD.20150409_SN.59196-01_DF.NC
# processing---> 10 / 14 files
# currently working with file--> /tmp/ssusi/f16/20150409/PS.APL_V0116S024CE0018_SC.U_DI.A_GP.F16-SSUSI_PA.APL-SDR-DISK_DD.20150409_SN.59205-00_DF.NC
# processing---> 11 / 14 files
# currently working with file--> /tmp/ssusi/f16/20150409/PS.APL_V0116S024CE0018_SC.U_DI.A_GP.F16-SSUSI_PA.APL-SDR-DISK_DD.20150409_SN.59203-00_DF.NC
# processing---> 12 / 14 files
# currently working with file--> /tmp/ssusi/f16/20150409/PS.APL_V0116S024CE0018_SC.U_DI.A_GP.F16-SSUSI_PA.APL-SDR-DISK_DD.20150409_SN.59200-00_DF.NC
# processing---> 13 / 14 files
# currently working with file--> /tmp/ssusi/f16/20150409/PS.APL_V0116S024CE0018_SC.U_DI.A_GP.F16-SSUSI_PA.APL-SDR-DISK_DD.20150409_SN.59204-00_DF.NC
# processing---> 14 / 14 files
# processing data -->  2015-04-09  sat--> f17
# currently working with file--> /tmp/ssusi/f17/20110409/PS.APL_V0116S024CE0008_SC.U_DI.A_GP.F17-SSUSI_PA.APL-SDR-DISK_DD.20110409_SN.22838-00_DF.NC
# processing---> 1 / 14 files
# currently working with file--> /tmp/ssusi/f17/20110409/PS.APL_V0116S024CE0008_SC.U_DI.A_GP.F17-SSUSI_PA.APL-SDR-DISK_DD.20110409_SN.22840-00_DF.NC
# processing---> 2 / 14 files
# currently working with file--> /tmp/ssusi/f17/20110409/PS.APL_V0116S024CE0008_SC.U_DI.A_GP.F17-SSUSI_PA.APL-SDR-DISK_DD.20110409_SN.22843-02_DF.NC
# processing---> 3 / 14 files
# currently working with file--> /tmp/ssusi/f17/20110409/PS.APL_V0116S024CE0008_SC.U_DI.A_GP.F17-SSUSI_PA.APL-SDR-DISK_DD.20110409_SN.22835-01_DF.NC
# processing---> 4 / 14 files
# currently working with file--> /tmp/ssusi/f17/20110409/PS.APL_V0116S024CE0008_SC.U_DI.A_GP.F17-SSUSI_PA.APL-SDR-DISK_DD.20110409_SN.22842-00_DF.NC
# processing---> 5 / 14 files
# currently working with file--> /tmp/ssusi/f17/20110409/PS.APL_V0116S024CE0008_SC.U_DI.A_GP.F17-SSUSI_PA.APL-SDR-DISK_DD.20110409_SN.22839-00_DF.NC
# processing---> 6 / 14 files
# currently working with file--> /tmp/ssusi/f17/20110409/PS.APL_V0116S024CE0008_SC.U_DI.A_GP.F17-SSUSI_PA.APL-SDR-DISK_DD.20110409_SN.22841-00_DF.NC
# processing---> 7 / 14 files
# currently working with file--> /tmp/ssusi/f17/20110409/PS.APL_V0116S024CE0008_SC.U_DI.A_GP.F17-SSUSI_PA.APL-SDR-DISK_DD.20110409_SN.22836-00_DF.NC
# processing---> 8 / 14 files
# currently working with file--> /tmp/ssusi/f17/20110409/PS.APL_V0116S024CE0008_SC.U_DI.A_GP.F17-SSUSI_PA.APL-SDR-DISK_DD.20110409_SN.22834-00_DF.NC
# processing---> 9 / 14 files
# currently working with file--> /tmp/ssusi/f17/20110409/PS.APL_V0116S024CE0008_SC.U_DI.A_GP.F17-SSUSI_PA.APL-SDR-DISK_DD.20110409_SN.22833-00_DF.NC
# processing---> 10 / 14 files
# currently working with file--> /tmp/ssusi/f17/20110409/PS.APL_V0116S024CE0008_SC.U_DI.A_GP.F17-SSUSI_PA.APL-SDR-DISK_DD.20110409_SN.22844-02_DF.NC
# processing---> 11 / 14 files
# currently working with file--> /tmp/ssusi/f17/20110409/PS.APL_V0116S024CE0008_SC.U_DI.A_GP.F17-SSUSI_PA.APL-SDR-DISK_DD.20110409_SN.22837-00_DF.NC
# processing---> 12 / 14 files
# currently working with file--> /tmp/ssusi/f17/20110409/PS.APL_V0116S024CE0008_SC.U_DI.A_GP.F17-SSUSI_PA.APL-SDR-DISK_DD.20110409_SN.22845-00_DF.NC
# processing---> 13 / 14 files
# currently working with file--> /tmp/ssusi/f17/20110409/PS.APL_V0116S024CE0008_SC.U_DI.A_GP.F17-SSUSI_PA.APL-SDR-DISK_DD.20110409_SN.22832-00_DF.NC
# processing---> 14 / 14 files
# processing data -->  2015-04-09  sat--> f17
# currently working with file--> /tmp/ssusi/f17/20150409/PS.APL_V0116S024CE0008_SC.U_DI.A_GP.F17-SSUSI_PA.APL-SDR-DISK_DD.20150409_SN.43479-00_DF.NC
# processing---> 1 / 14 files
# currently working with file--> /tmp/ssusi/f17/20150409/PS.APL_V0116S024CE0008_SC.U_DI.A_GP.F17-SSUSI_PA.APL-SDR-DISK_DD.20150409_SN.43473-00_DF.NC
# processing---> 2 / 14 files
# currently working with file--> /tmp/ssusi/f17/20150409/PS.APL_V0116S024CE0008_SC.U_DI.A_GP.F17-SSUSI_PA.APL-SDR-DISK_DD.20150409_SN.43480-00_DF.NC
# processing---> 3 / 14 files
# currently working with file--> /tmp/ssusi/f17/20150409/PS.APL_V0116S024CE0008_SC.U_DI.A_GP.F17-SSUSI_PA.APL-SDR-DISK_DD.20150409_SN.43484-00_DF.NC
# processing---> 4 / 14 files
# currently working with file--> /tmp/ssusi/f17/20150409/PS.APL_V0116S024CE0008_SC.U_DI.A_GP.F17-SSUSI_PA.APL-SDR-DISK_DD.20150409_SN.43483-00_DF.NC
# processing---> 5 / 14 files
# currently working with file--> /tmp/ssusi/f17/20150409/PS.APL_V0116S024CE0008_SC.U_DI.A_GP.F17-SSUSI_PA.APL-SDR-DISK_DD.20150409_SN.43477-01_DF.NC
# processing---> 6 / 14 files
# currently working with file--> /tmp/ssusi/f17/20150409/PS.APL_V0116S024CE0008_SC.U_DI.A_GP.F17-SSUSI_PA.APL-SDR-DISK_DD.20150409_SN.43481-00_DF.NC
# processing---> 7 / 14 files
# currently working with file--> /tmp/ssusi/f17/20150409/PS.APL_V0116S024CE0008_SC.U_DI.A_GP.F17-SSUSI_PA.APL-SDR-DISK_DD.20150409_SN.43485-01_DF.NC
# processing---> 8 / 14 files
# currently working with file--> /tmp/ssusi/f17/20150409/PS.APL_V0116S024CE0008_SC.U_DI.A_GP.F17-SSUSI_PA.APL-SDR-DISK_DD.20150409_SN.43472-00_DF.NC
# processing---> 9 / 14 files
# currently working with file--> /tmp/ssusi/f17/20150409/PS.APL_V0116S024CE0008_SC.U_DI.A_GP.F17-SSUSI_PA.APL-SDR-DISK_DD.20150409_SN.43474-00_DF.NC
# processing---> 10 / 14 files
# currently working with file--> /tmp/ssusi/f17/20150409/PS.APL_V0116S024CE0008_SC.U_DI.A_GP.F17-SSUSI_PA.APL-SDR-DISK_DD.20150409_SN.43478-00_DF.NC
# processing---> 11 / 14 files
# currently working with file--> /tmp/ssusi/f17/20150409/PS.APL_V0116S024CE0008_SC.U_DI.A_GP.F17-SSUSI_PA.APL-SDR-DISK_DD.20150409_SN.43475-01_DF.NC
# processing---> 12 / 14 files
# currently working with file--> /tmp/ssusi/f17/20150409/PS.APL_V0116S024CE0008_SC.U_DI.A_GP.F17-SSUSI_PA.APL-SDR-DISK_DD.20150409_SN.43482-00_DF.NC
# processing---> 13 / 14 files
# currently working with file--> /tmp/ssusi/f17/20150409/PS.APL_V0116S024CE0008_SC.U_DI.A_GP.F17-SSUSI_PA.APL-SDR-DISK_DD.20150409_SN.43476-00_DF.NC
# processing---> 14 / 14 files
# processing data -->  2015-04-09  sat--> f18
# currently working with file--> /tmp/ssusi/f18/20110409/PS.APL_V0116S024CB0005_SC.U_DI.A_GP.F18-SSUSI_PA.APL-SDR-DISK_DD.20110409_SN.07593-00_DF.NC
# processing---> 1 / 14 files
# currently working with file--> /tmp/ssusi/f18/20110409/PS.APL_V0116S024CB0005_SC.U_DI.A_GP.F18-SSUSI_PA.APL-SDR-DISK_DD.20110409_SN.07589-00_DF.NC
# processing---> 2 / 14 files
# currently working with file--> /tmp/ssusi/f18/20110409/PS.APL_V0116S024CB0005_SC.U_DI.A_GP.F18-SSUSI_PA.APL-SDR-DISK_DD.20110409_SN.07592-00_DF.NC
# processing---> 3 / 14 files
# currently working with file--> /tmp/ssusi/f18/20110409/PS.APL_V0116S024CB0005_SC.U_DI.A_GP.F18-SSUSI_PA.APL-SDR-DISK_DD.20110409_SN.07595-00_DF.NC
# processing---> 4 / 14 files
# currently working with file--> /tmp/ssusi/f18/20110409/PS.APL_V0116S024CB0005_SC.U_DI.A_GP.F18-SSUSI_PA.APL-SDR-DISK_DD.20110409_SN.07597-00_DF.NC
# processing---> 5 / 14 files
# currently working with file--> /tmp/ssusi/f18/20110409/PS.APL_V0116S024CB0005_SC.U_DI.A_GP.F18-SSUSI_PA.APL-SDR-DISK_DD.20110409_SN.07599-00_DF.NC
# processing---> 6 / 14 files
# currently working with file--> /tmp/ssusi/f18/20110409/PS.APL_V0116S024CB0005_SC.U_DI.A_GP.F18-SSUSI_PA.APL-SDR-DISK_DD.20110409_SN.07588-00_DF.NC
# processing---> 7 / 14 files
# currently working with file--> /tmp/ssusi/f18/20110409/PS.APL_V0116S024CB0005_SC.U_DI.A_GP.F18-SSUSI_PA.APL-SDR-DISK_DD.20110409_SN.07587-00_DF.NC
# processing---> 8 / 14 files
# currently working with file--> /tmp/ssusi/f18/20110409/PS.APL_V0116S024CB0005_SC.U_DI.A_GP.F18-SSUSI_PA.APL-SDR-DISK_DD.20110409_SN.07594-00_DF.NC
# processing---> 9 / 14 files
# currently working with file--> /tmp/ssusi/f18/20110409/PS.APL_V0116S024CB0005_SC.U_DI.A_GP.F18-SSUSI_PA.APL-SDR-DISK_DD.20110409_SN.07598-00_DF.NC
# processing---> 10 / 14 files
# currently working with file--> /tmp/ssusi/f18/20110409/PS.APL_V0116S024CB0005_SC.U_DI.A_GP.F18-SSUSI_PA.APL-SDR-DISK_DD.20110409_SN.07591-01_DF.NC
# processing---> 11 / 14 files
# currently working with file--> /tmp/ssusi/f18/20110409/PS.APL_V0116S024CB0005_SC.U_DI.A_GP.F18-SSUSI_PA.APL-SDR-DISK_DD.20110409_SN.07586-00_DF.NC
# processing---> 12 / 14 files
# currently working with file--> /tmp/ssusi/f18/20110409/PS.APL_V0116S024CB0005_SC.U_DI.A_GP.F18-SSUSI_PA.APL-SDR-DISK_DD.20110409_SN.07590-00_DF.NC
# processing---> 13 / 14 files
# currently working with file--> /tmp/ssusi/f18/20110409/PS.APL_V0116S024CB0005_SC.U_DI.A_GP.F18-SSUSI_PA.APL-SDR-DISK_DD.20110409_SN.07596-00_DF.NC
# processing---> 14 / 14 files
# processing data -->  2015-04-09  sat--> f18
# currently working with file--> /tmp/ssusi/f18/20150409/PS.APL_V0116S024CB0005_SC.U_DI.A_GP.F18-SSUSI_PA.APL-SDR-DISK_DD.20150409_SN.28219-00_DF.NC
# processing---> 1 / 14 files
# currently working with file--> /tmp/ssusi/f18/20150409/PS.APL_V0116S024CB0005_SC.U_DI.A_GP.F18-SSUSI_PA.APL-SDR-DISK_DD.20150409_SN.28216-00_DF.NC
# processing---> 2 / 14 files
# currently working with file--> /tmp/ssusi/f18/20150409/PS.APL_V0116S024CB0005_SC.U_DI.A_GP.F18-SSUSI_PA.APL-SDR-DISK_DD.20150409_SN.28224-00_DF.NC
# processing---> 3 / 14 files
# currently working with file--> /tmp/ssusi/f18/20150409/PS.APL_V0116S024CB0005_SC.U_DI.A_GP.F18-SSUSI_PA.APL-SDR-DISK_DD.20150409_SN.28222-00_DF.NC
# processing---> 4 / 14 files
# currently working with file--> /tmp/ssusi/f18/20150409/PS.APL_V0116S024CB0005_SC.U_DI.A_GP.F18-SSUSI_PA.APL-SDR-DISK_DD.20150409_SN.28217-00_DF.NC
# processing---> 5 / 14 files
# currently working with file--> /tmp/ssusi/f18/20150409/PS.APL_V0116S024CB0005_SC.U_DI.A_GP.F18-SSUSI_PA.APL-SDR-DISK_DD.20150409_SN.28221-01_DF.NC
# processing---> 6 / 14 files
# currently working with file--> /tmp/ssusi/f18/20150409/PS.APL_V0116S024CB0005_SC.U_DI.A_GP.F18-SSUSI_PA.APL-SDR-DISK_DD.20150409_SN.28223-00_DF.NC
# processing---> 7 / 14 files
# currently working with file--> /tmp/ssusi/f18/20150409/PS.APL_V0116S024CB0005_SC.U_DI.A_GP.F18-SSUSI_PA.APL-SDR-DISK_DD.20150409_SN.28215-00_DF.NC
# processing---> 8 / 14 files
# currently working with file--> /tmp/ssusi/f18/20150409/PS.APL_V0116S024CB0005_SC.U_DI.A_GP.F18-SSUSI_PA.APL-SDR-DISK_DD.20150409_SN.28220-00_DF.NC
# processing---> 9 / 14 files
# currently working with file--> /tmp/ssusi/f18/20150409/PS.APL_V0116S024CB0005_SC.U_DI.A_GP.F18-SSUSI_PA.APL-SDR-DISK_DD.20150409_SN.28218-00_DF.NC
# processing---> 10 / 14 files
# currently working with file--> /tmp/ssusi/f18/20150409/PS.APL_V0116S024CB0005_SC.U_DI.A_GP.F18-SSUSI_PA.APL-SDR-DISK_DD.20150409_SN.28226-00_DF.NC
# processing---> 11 / 14 files
# currently working with file--> /tmp/ssusi/f18/20150409/PS.APL_V0116S024CB0005_SC.U_DI.A_GP.F18-SSUSI_PA.APL-SDR-DISK_DD.20150409_SN.28227-00_DF.NC
# processing---> 12 / 14 files
# currently working with file--> /tmp/ssusi/f18/20150409/PS.APL_V0116S024CB0005_SC.U_DI.A_GP.F18-SSUSI_PA.APL-SDR-DISK_DD.20150409_SN.28225-00_DF.NC
# processing---> 13 / 14 files
# currently working with file--> /tmp/ssusi/f18/20150409/PS.APL_V0116S024CB0005_SC.U_DI.A_GP.F18-SSUSI_PA.APL-SDR-DISK_DD.20150409_SN.28228-00_DF.NC
# processing---> 14 / 14 files

# %%
# The directory where files are stored
# NOTE : ONLY FILES in specific format
# can be read. So make sure you download
# using the procedure defined in the 
# "download_files" notebook.
rawFileDir = "/tmp/timed/" # Make sure you have this dir or create it
prcsdFileDir = "/tmp/timed/prcsd/" # Make sure you have this dir or create it
currDate = datetime.datetime( 2005, 8, 6 )
endDate = datetime.datetime( 2005, 8, 6 )
tDelta = datetime.timedelta(days=1)
while currDate <= endDate:
    for root, dirs, files in os.walk(rawFileDir):
        for nd, dd in enumerate(dirs):
            print "processing data --> ",\
                     currDate.strftime("%Y-%m-%d")
            tgRdObj = read_timed_guvi.ProcessTGData( [root + dd + "/"],\
                         prcsdFileDir, currDate )
            tgRdObj.processed_data_to_file()
    currDate += tDelta
# Out:
# processing data -->  2005-08-06
# ['/tmp/timed/20020318/TIMED_GUVI_L1C-2-disk-IMG_2002077192452-2002077210207_REV01497_Av13-01r001.nc', '/tmp/timed/20020318/TIMED_GUVI_L1C-2-disk-IMG_2002077210207-2002077223922_REV01498_Av13-01r001.nc', '/tmp/timed/20020318/TIMED_GUVI_L1C-2-disk-IMG_2002077174737-2002077192452_REV01496_Av13-01r001.nc', '/tmp/timed/20020318/TIMED_GUVI_L1C-2-disk-IMG_2002077080407-2002077094122_REV01490_Av13-01r001.nc', '/tmp/timed/20020318/TIMED_GUVI_L1C-2-disk-IMG_2002077125552-2002077143307_REV01493_Av13-01r001.nc', '/tmp/timed/20020318/TIMED_GUVI_L1C-2-disk-IMG_2002077044936-2002077062652_REV01488_Av13-01r001.nc', '/tmp/timed/20020318/TIMED_GUVI_L1C-2-disk-IMG_2002077094122-2002077111837_REV01491_Av13-01r001.nc', '/tmp/timed/20020318/TIMED_GUVI_L1C-2-disk-IMG_2002077062652-2002077080407_REV01489_Av13-01r001.nc', '/tmp/timed/20020318/TIMED_GUVI_L1C-2-disk-IMG_2002077013506-2002077031221_REV01486_Av13-01r001.nc', '/tmp/timed/20020318/TIMED_GUVI_L1C-2-disk-IMG_2002077143307-2002077161022_REV01494_Av13-01r001.nc', '/tmp/timed/20020318/TIMED_GUVI_L1C-2-disk-IMG_2002077161022-2002077174737_REV01495_Av13-01r001.nc', '/tmp/timed/20020318/TIMED_GUVI_L1C-2-disk-IMG_2002077111837-2002077125552_REV01492_Av13-01r001.nc', '/tmp/timed/20020318/TIMED_GUVI_L1C-2-disk-IMG_2002077223922-2002078001637_REV01499_Av13-01r001.nc', '/tmp/timed/20020318/TIMED_GUVI_L1C-2-disk-IMG_2002077031221-2002077044936_REV01487_Av13-01r001.nc']
# currently working with file--> /tmp/timed/20020318/TIMED_GUVI_L1C-2-disk-IMG_2002077192452-2002077210207_REV01497_Av13-01r001.nc
# processing---> 1 / 14 files
# /tmp/timed/20020318/TIMED_GUVI_L1C-2-disk-IMG_2002077192452-2002077210207_REV01497_Av13-01r001.nc
# currently working with file--> /tmp/timed/20020318/TIMED_GUVI_L1C-2-disk-IMG_2002077210207-2002077223922_REV01498_Av13-01r001.nc
# processing---> 2 / 14 files
# /tmp/timed/20020318/TIMED_GUVI_L1C-2-disk-IMG_2002077210207-2002077223922_REV01498_Av13-01r001.nc
# currently working with file--> /tmp/timed/20020318/TIMED_GUVI_L1C-2-disk-IMG_2002077174737-2002077192452_REV01496_Av13-01r001.nc
# processing---> 3 / 14 files
# /tmp/timed/20020318/TIMED_GUVI_L1C-2-disk-IMG_2002077174737-2002077192452_REV01496_Av13-01r001.nc
# currently working with file--> /tmp/timed/20020318/TIMED_GUVI_L1C-2-disk-IMG_2002077080407-2002077094122_REV01490_Av13-01r001.nc
# processing---> 4 / 14 files
# /tmp/timed/20020318/TIMED_GUVI_L1C-2-disk-IMG_2002077080407-2002077094122_REV01490_Av13-01r001.nc
# currently working with file--> /tmp/timed/20020318/TIMED_GUVI_L1C-2-disk-IMG_2002077125552-2002077143307_REV01493_Av13-01r001.nc
# processing---> 5 / 14 files
# /tmp/timed/20020318/TIMED_GUVI_L1C-2-disk-IMG_2002077125552-2002077143307_REV01493_Av13-01r001.nc
# currently working with file--> /tmp/timed/20020318/TIMED_GUVI_L1C-2-disk-IMG_2002077044936-2002077062652_REV01488_Av13-01r001.nc
# processing---> 6 / 14 files
# /tmp/timed/20020318/TIMED_GUVI_L1C-2-disk-IMG_2002077044936-2002077062652_REV01488_Av13-01r001.nc
# currently working with file--> /tmp/timed/20020318/TIMED_GUVI_L1C-2-disk-IMG_2002077094122-2002077111837_REV01491_Av13-01r001.nc
# processing---> 7 / 14 files
# /tmp/timed/20020318/TIMED_GUVI_L1C-2-disk-IMG_2002077094122-2002077111837_REV01491_Av13-01r001.nc
# currently working with file--> /tmp/timed/20020318/TIMED_GUVI_L1C-2-disk-IMG_2002077062652-2002077080407_REV01489_Av13-01r001.nc
# processing---> 8 / 14 files
# /tmp/timed/20020318/TIMED_GUVI_L1C-2-disk-IMG_2002077062652-2002077080407_REV01489_Av13-01r001.nc
# currently working with file--> /tmp/timed/20020318/TIMED_GUVI_L1C-2-disk-IMG_2002077013506-2002077031221_REV01486_Av13-01r001.nc
# processing---> 9 / 14 files
# /tmp/timed/20020318/TIMED_GUVI_L1C-2-disk-IMG_2002077013506-2002077031221_REV01486_Av13-01r001.nc
# currently working with file--> /tmp/timed/20020318/TIMED_GUVI_L1C-2-disk-IMG_2002077143307-2002077161022_REV01494_Av13-01r001.nc
# processing---> 10 / 14 files
# /tmp/timed/20020318/TIMED_GUVI_L1C-2-disk-IMG_2002077143307-2002077161022_REV01494_Av13-01r001.nc
# currently working with file--> /tmp/timed/20020318/TIMED_GUVI_L1C-2-disk-IMG_2002077161022-2002077174737_REV01495_Av13-01r001.nc
# processing---> 11 / 14 files
# /tmp/timed/20020318/TIMED_GUVI_L1C-2-disk-IMG_2002077161022-2002077174737_REV01495_Av13-01r001.nc
# currently working with file--> /tmp/timed/20020318/TIMED_GUVI_L1C-2-disk-IMG_2002077111837-2002077125552_REV01492_Av13-01r001.nc
# processing---> 12 / 14 files
# /tmp/timed/20020318/TIMED_GUVI_L1C-2-disk-IMG_2002077111837-2002077125552_REV01492_Av13-01r001.nc
# currently working with file--> /tmp/timed/20020318/TIMED_GUVI_L1C-2-disk-IMG_2002077223922-2002078001637_REV01499_Av13-01r001.nc
# processing---> 13 / 14 files
# /tmp/timed/20020318/TIMED_GUVI_L1C-2-disk-IMG_2002077223922-2002078001637_REV01499_Av13-01r001.nc
# currently working with file--> /tmp/timed/20020318/TIMED_GUVI_L1C-2-disk-IMG_2002